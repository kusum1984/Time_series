# %% [markdown]
# <a href="https://colab.research.google.com/github/kusum1984/Time_series/blob/main/Timeseries_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
####Time Series EDA
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
#pdr.get_data_yahoo('TSLA')

# %%
# !pip install --upgrade pandas-datareader

# %%
# !pip install yfinance
import yfinance as yf

data = yf.download('TSLA')
# Out:
# ...
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-01-22  212.259995  217.800003  206.270004  208.800003  208.800003
# 2024-01-23  211.300003  215.649994  207.750000  209.139999  209.139999
# 2024-01-24  211.880005  212.729996  206.770004  207.830002  207.830002
# 2024-01-25  189.699997  193.000000  180.059998  182.630005  182.630005
# 2024-01-26  185.500000  186.779999  182.100006  183.250000  183.250000
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
df_tesla=data

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
#display first five rows of the dataset
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
#Display last five rows of dataset
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-22  212.259995  217.800003  206.270004  208.800003  208.800003
# 2024-01-23  211.300003  215.649994  207.750000  209.139999  209.139999
# 2024-01-24  211.880005  212.729996  206.770004  207.830002  207.830002
# 2024-01-25  189.699997  193.000000  180.059998  182.630005  182.630005
# 2024-01-26  185.500000  186.779999  182.100006  183.250000  183.250000
#
#                Volume
# Date
# 2024-01-22  117952500
# 2024-01-23  106605900
# 2024-01-24  123369900
# 2024-01-25  198076800
# 2024-01-26  107063400

# %%
#Ploting dataset
df_tesla.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#ploting with respect to high column
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
#Providing X limit and Y limit in the plot
df_tesla['High'].plot(xlim=['2020-01-01','2024-01-26'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].plot(xlim=['2020-01-01','2024-01-26'],ylim=[0,500],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
#coloring the plot
df_tesla['High'].plot(xlim=['2020-01-01','2024-01-26'],ylim=[0,500],c='red', ls='--',figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-01-12', '2024-01-16', '2024-01-17', '2024-01-18',
#                '2024-01-19', '2024-01-22', '2024-01-23', '2024-01-24',
#                '2024-01-25', '2024-01-26'],
#               dtype='datetime64[ns]', name='Date', length=3418, freq=None)

# %%
#Reading rows
index=df_tesla.loc['2020-01-01':'2024-01-26'].index
share_open=df_tesla.loc['2020-01-01':'2024-01-26']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2024-01-22    212.259995
# 2024-01-23    211.300003
# 2024-01-24    211.880005
# 2024-01-25    189.699997
# 2024-01-26    185.500000
# Name: Open, Length: 1024, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Drawing subplot
figure,axis=plt.subplots()
plt.tight_layout()# To fix the date display
figure.autofmt_xdate()#Alternate way to fix date display

axis.plot(index,share_open)

# %%
#Datetime Index
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3418 entries, 2010-06-29 to 2024-01-26
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3418 non-null   float64
#  1   High       3418 non-null   float64
#  2   Low        3418 non-null   float64
#  3   Close      3418 non-null   float64
#  4   Adj Close  3418 non-null   float64
#  5   Volume     3418 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 316.0 KB

# %%
df_tesla.reset_index()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3413 2024-01-22  212.259995  217.800003  206.270004  208.800003  208.800003
# 3414 2024-01-23  211.300003  215.649994  207.750000  209.139999  209.139999
# 3415 2024-01-24  211.880005  212.729996  206.770004  207.830002  207.830002
# 3416 2024-01-25  189.699997  193.000000  180.059998  182.630005  182.630005
# 3417 2024-01-26  185.500000  186.779999  182.100006  183.250000  183.250000
#
#          Volume
# 0     281494500
# 1     257806500
# ...

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3418 entries, 2010-06-29 to 2024-01-26
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3418 non-null   float64
#  1   High       3418 non-null   float64
#  2   Low        3418 non-null   float64
#  3   Close      3418 non-null   float64
#  4   Adj Close  3418 non-null   float64
#  5   Volume     3418 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 316.0 KB

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-01-22  212.259995  217.800003  206.270004  208.800003  208.800003
# 2024-01-23  211.300003  215.649994  207.750000  209.139999  209.139999
# 2024-01-24  211.880005  212.729996  206.770004  207.830002  207.830002
# 2024-01-25  189.699997  193.000000  180.059998  182.630005  182.630005
# 2024-01-26  185.500000  186.779999  182.100006  183.250000  183.250000
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
#df_tesal=df_tesla.set_index('Date',drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-0d809d148d15> in <cell line: 1>()
# ----> 1 df_tesal=df_tesla.set_index('Date',drop=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
df_tesla

# %%
#datatime
from datetime import datetime

# %%
datetime(2021,11,21)

# %%
datetime.now()

# %%
#to see how much time it is executed
def add_num(num1,num2):
    return num1+num2

# %%
start_time =datetime.now()
num1=10
num2=1000000000000000
add_num(num1,num2)
end_time=datetime.now()
print(end_time-start_time)

# %%
date=datetime(2024,1,26)

# %%
date

# %%
date.date()

# %%
date.day

# %%
date.weekday()

# %%
date.year

# %%
date.hour

# %%
date.month

# %% [markdown]
# ## **Time resampling**

# %%
df_tesla.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
#Max shares in a year
df_tesla.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
#plotting with respect to Open column
#Rule A is year end frequency
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Quartly frequency
df_tesla.resample(rule='QS').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Quartly frequency
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Business End frequency
df_tesla.resample(rule='BA').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Business Quarter freqyency
df_tesla.resample(rule='BQS').max().plot

# %%
df_tesla['Open'].resample(rule='BA').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').max().plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
#Finding rolling mean/mean average
df_tesla['High'].rolling(10).max().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13    2.028000
# 2010-07-14    2.028000
# 2010-07-15    1.728000
# 2010-07-16    1.540000
# 2010-07-19    1.483333
# 2010-07-20    1.483333
# 2010-07-21    1.483333
# 2010-07-22    1.483333
# 2010-07-23    1.483333
# 2010-07-26    1.483333
# 2010-07-27    1.483333
# Name: High, dtype: float64

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(30)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
df_tesla[['Open','Open:30 days rolling']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Simple moving average for the smoothing of the graph
df_tesla['Open'].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open:10 days rolling']=df_tesla['Open'].rolling(window=10,min_periods=1).mean()

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#             Open:30 days rolling  Open:10 days rolling
# Date
# 2010-06-29                   NaN              1.266667
# 2010-06-30                   NaN              1.493000
# 2010-07-01                   NaN              1.550889
# 2010-07-02                   NaN              1.546500
# 2010-07-06                   NaN              1.503867

# %%
df_tesla[['Open:10 days rolling','Open','Open:30 days rolling']].plot(xlim=['2023-01-01','2024-01-26'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
##Expanding/CMA
df_tesla['Open'].expanding().mean().plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
#Smoothing factor -0.1
df_tesla['EMA_0.1']=df_tesla['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1']].plot(xlim=['2020-01-01','2024-01-26'])
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['EMA_0.3']=df_tesla['Open'].ewm(alpha=0.3,adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.3','EMA_0.1']].plot(xlim=['2020-01-01','2024-01-26'])
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['EMA_5days']=df_tesla['Open'].ewm(span=5).mean()

# %%
df_tesla[['Open','EMA_5days']].plot(figsize=(20,8))
# Out:
# <Axes: xlabel='Date'>
